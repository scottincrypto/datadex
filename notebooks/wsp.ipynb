# %%
import pandas as pd

# %%
df = pd.read_excel("../data/scott WSP.xlsx", 'OrderExport00')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Columns: 103 entries, Order to Cost Centre Group 10
# dtypes: datetime64[ns](8), float64(23), int64(21), object(51)
# memory usage: 247.2+ KB

# %%
df['year'] = df['Order Date'].dt.year

# %%
df
# Out:
#       Order  Item Vendor Number Vendor Name Key         Vendor Description  \
# 0    407003     1        PPK002         PARSONS  WSP Australia Pty Limited
# 1    408183     1        PPK002         PARSONS  WSP Australia Pty Limited
# 2    408184     1        PPK002         PARSONS  WSP Australia Pty Limited
# 3    408654     1        PPK002         PARSONS  WSP Australia Pty Limited
# 4    410489     1        PPK002         PARSONS  WSP Australia Pty Limited
# ..      ...   ...           ...             ...                        ...
# 302  569021     1        PPK002         PARSONS  WSP Australia Pty Limited
# 303  569261     1        PPK002         PARSONS  WSP Australia Pty Limited
# 304  570696     1        PPK002         PARSONS  WSP Australia Pty Limited
# 305  571163     1        PPK002         PARSONS  WSP Australia Pty Limited
# 306  573678     1        PPK002         PARSONS  WSP Australia Pty Limited
#
#                                      Order Description Category  \
# ...
